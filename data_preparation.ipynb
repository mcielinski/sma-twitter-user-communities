# %%
import twint
import pandas as pd
import numpy as np
from functools import reduce
import datetime
from tqdm import tqdm
import nest_asyncio
nest_asyncio.apply()

# %%
def search_scraper(search_phrase, file_path):
    # Configure
    c = twint.Config()
    
    # Twitter user's username
    #c.Username = username
    
    # Search terms
    c.Search = search_phrase
    
    # Filter Tweets sent since date, works only with twint.run.Search (Example: 2017-12-27).
    c.Since = '2020-10-22'
    # Filter Tweets sent until date, works only with twint.run.Search (Example: 2017-12-27).
    c.Until = '2020-10-24'
    
    # Get retweets done by the user.
    #c.Retweets = True
    
    # Name of the output file.
    c.Output = file_path
    
    # Set to True to write as a csv file.
    c.Tabs = True
    c.Store_csv = True
    
    # Hide output.
    c.Hide_output = True
    
    # Run
    twint.run.Search(c)
    #twint.run.Profile(c)

# %%
def profile_scraper(username, file_path):
    # Configure
    c = twint.Config()
    
    # Twitter user's username
    c.Username = username
    
    # Search terms
    #c.Search = search_ph
    
    # Filter Tweets sent since date, works only with twint.run.Search (Example: 2017-12-27).
    c.Since = '2020-10-15'
    # Filter Tweets sent until date, works only with twint.run.Search (Example: 2017-12-27).
    #c.Until = '2020-10-19'
    
    # Get retweets done by the user.
    c.Retweets = True
    
    # Set to True to display full user information. By default, only usernames are shown.
    #c.User_full = True
    c.Profile_full = True
    
    # Name of the output file.
    c.Output = file_path
    
    # Set to True to write as a csv file.
    c.Tabs = True
    c.Store_csv = True
    
    # Hide output.
    c.Hide_output = True
    
    # Run
    #twint.run.Search(c)
    twint.run.Profile(c)

# %% [markdown]
# ### Search phrase

# %%
#filename_part = 'StrajKobiet_'
filename_part = 'zakazaborcji'
#filename_part = 'TrybunałKonstytucyjny'
#filename_part = 'wypierdalać'
#filename_part = 'AferaSzumowskiego'

file_path = 'data/' + filename_part + '.csv'

# %%
#search_phrase = '#StrajKobiet'
search_phrase = '#zakazaborcji'
#search_phrase = '#TrybunałKonstytucyjny'
#search_phrase = '#wypierdalać'
#search_phrase = '#AferaSzumowskiego'

search_scraper(search_phrase=search_phrase, 
               file_path=file_path)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %% [markdown]
# ### Profile

# %%
file = file_path

#df = pd.read_csv(file, sep='\t', usecols=attributes_tweets, index_col='id')
df = pd.read_csv(file, sep='\t', index_col='id')

df.shape
# Out:
# (3023, 35)

# %%
users_list = list(df['username'].unique())

len(users_list)
# Out:
# 1966

# %%
filelist = []
filename_part = 'data/users/'

for user in users_list:
    filelist.append(filename_part + user + '.csv')

filelist[:10]
# Out:
# ['data/users/krzlew88.csv',
#  'data/users/krytyka.csv',
#  'data/users/mihashi_chan.csv',
#  'data/users/jacekpiotrowitz.csv',
#  'data/users/realolamilka.csv',
#  'data/users/tslm06.csv',
#  'data/users/_keonibear_.csv',
#  'data/users/kuba31745287.csv',
#  'data/users/leodille.csv',
#  'data/users/whatnow273.csv']

# %%
#for i in range(10):
for i in range(len(users_list)):
    #profile_scraper(users_list[i], filelist[i])
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 289 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 71 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 691 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 99 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 46 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 85 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 139 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 47 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 157 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 21 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 220 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 74 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 136 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 296 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 199 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 406 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 39 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 329 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 173 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 32 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 36 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 163 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 65 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 28 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 52 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 350 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 17 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 276 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 249 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 117 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 82 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 55 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 34 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 14 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 227 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 70 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 350 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 237 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 18 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 51 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 18 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 14 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 50 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 419 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 24 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 45 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 50 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 374 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 33 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 48 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 32 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 131 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 46 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 886 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 86 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 49 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 143 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 244 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 108 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 101 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 85 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 36 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 80 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 14 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 131 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 112 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 57 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 70 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 128 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 31 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 56 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 385 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 138 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 377 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 89 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 38 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 110 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 213 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 19 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 217 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 576 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 25 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 74 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 42 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 40 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 90 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 56 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 31 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 52 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 30 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 31 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 294 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 98 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 203 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 51 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 46 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 21 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 14 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 27 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 120 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 17 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 146 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 109 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 373 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 86 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 102 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 103 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 40 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 156 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 58 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 44 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 104 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 72 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 107 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 67 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 42 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 28 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 26 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 99 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 21 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 211 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 543 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 102 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 24 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 153 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 26 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] Twitter does not return more data, scrape stops here.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 31 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 343 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 37 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 84 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 141 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 28 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 327 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 101 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 173 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 11 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 121 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 148 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] Twitter does not return more data, scrape stops here.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 231 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 26 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 223 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 63 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 32 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 42 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 34 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 20 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 350 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 217 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 288 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 101 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 118 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 16 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 80 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 38 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 51 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 19 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 25 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 61 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 32 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 23 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 48 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 99 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 71 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 50 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 18 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 49 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 299 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 61 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# ...
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 213 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 51 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 48 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 271 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 387 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 73 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 16 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 17 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 25 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 102 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 25 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 71 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 142 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 94 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 76 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 83 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 24 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 374 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 215 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 110 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 83 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 212 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 19 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 82 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 12 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 21 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 18 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 16 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 71 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 631 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 78 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 4 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 532 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 70 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 34 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 236 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 7 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 14 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 323 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 71 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 16 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 203 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 45 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 22 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 3 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 44 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 15 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 141 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 13 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 10 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 34 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 356 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 210 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 157 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 26 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 17 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 769 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 250 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 2 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 8 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 9 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 6 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 38 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 5 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 1 deleted tweets in this search.
